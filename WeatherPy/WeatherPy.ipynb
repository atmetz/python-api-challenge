# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rorvik
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | hami
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | amalapuram
# Processing Record 11 of Set 1 | baraki barak
# Processing Record 12 of Set 1 | sorland
# Processing Record 13 of Set 1 | mao
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | san cristobal
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | merced
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     rorvik  64.8621   11.2373      3.99       100          20        1.54
# 1   katsuura  35.1333  140.3000     18.85        50           5       11.25
# 2    rikitea -23.1203 -134.9692     25.00        68          49        6.17
# 3  carnarvon -24.8667  113.6333     22.80        55           8        5.08
# 4       hami  42.8000   93.4500     11.87        12           6        2.40
#
#   Country        Date
# 0      NO  1680920132
# 1      JP  1680920309
# 2      PF  1680920293
# 3      AU  1680920310
# 4      CN  1680920310

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           rorvik  64.8621   11.2373      3.99       100          20
# 1         katsuura  35.1333  140.3000     18.85        50           5
# 2          rikitea -23.1203 -134.9692     25.00        68          49
# 3        carnarvon -24.8667  113.6333     22.80        55           8
# 4             hami  42.8000   93.4500     11.87        12           6
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      NO  1680920132
# 1             11.25      JP  1680920309
# 2              6.17      PF  1680920293
# 3              5.08      AU  1680920310
# 4              2.40      CN  1680920310

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
plt.grid(visible=True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.grid(visible=True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.grid(visible=True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.grid(visible=True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def line_reg_plot(x_value, y_value, linex=0, liney=0):
    
    # Calculate linear regression equation and line
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_values = x_value * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Build scatter plot graph
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_values, "r-")
    plt.annotate(line_eq, (linex,liney), fontsize=15, color="red")
    
    # Display r squared value and scatter plot graph
    print("The r-value is: " + str(rvalue**2))
    #plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat'] >= 0])

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             rorvik  64.8621   11.2373      3.99       100          20
# 1           katsuura  35.1333  140.3000     18.85        50           5
# 4               hami  42.8000   93.4500     11.87        12           6
# 6        provideniya  64.3833 -173.3000    -18.52        70          22
# 8         amalapuram  16.5833   82.0167     27.47        67           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      NO  1680920132
# 1             11.25      JP  1680920309
# 4              2.40      CN  1680920310
# 6              1.53      RU  1680920310
# 8              0.48      IN  1680920311

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df['Lat'] < 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             rikitea -23.1203 -134.9692     25.00        68          49
# 3           carnarvon -24.8667  113.6333     22.80        55           8
# 5              faanui -16.4833 -151.7500     28.66        76          89
# 7              atuona  -9.8000 -139.0333     27.46        74          63
# 15       puerto ayora  -0.7393  -90.3518     26.42        89         100
#
#          Wind Speed Country        Date
# City_ID
# 2              6.17      PF  1680920293
# 3              5.08      AU  1680920310
# 5              9.61      PF  1680920310
# 7              8.78      PF  1680920311
# 15             1.41      EC  1680920313

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

# Call line_reg_plot function, pass variables for Latitude, Max Temp, x and y position of the line equation
line_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 0 , -15)
plt.show()
# Out:
# The r-value is: 0.77373246434784

# %%
# Linear regression on Southern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

# Call line_reg_plot function, pass variables for Latitude, Max Temp, x and y position of the line equation
line_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], -55, 30)
plt.show()
# Out:
# The r-value is: 0.4442170203502294

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Humidity %")

# Call line_reg_plot function, pass variables for Latitude, Humidity, x and y position of the line equation
line_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], 48, 13)
plt.show()
# Out:
# The r-value is: 0.04492183266379298

# %%
# Southern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Humidity %")

# Call line_reg_plot function, pass variables for Latitude, Humidity, x and y position of the line equation
line_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], -55, 25)
plt.show()
# Out:
# The r-value is: 0.10208825298288057

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

# Call line_reg_plot function, pass variables for Latitude, Cloudiness, x and y position of the line equation
line_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], 0, 0)
plt.show()
# Out:
# The r-value is: 0.006889138233197021

# %%
# Southern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

# Call line_reg_plot function, pass variables for Latitude, Cloudiness, x and y position of the line equation
line_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], -57, 60)
plt.show()
# Out:
# The r-value is: 0.09008492535910692

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Call line_reg_plot function, pass variables for Latitude, Wind Speed, x and y position of the line equation
line_reg_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], 0, 14)
plt.show()
# Out:
# The r-value is: 0.03308702568115154

# %%
# Southern Hemisphere
# Set X and Y Labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Call line_reg_plot function, pass variables for Latitude , Wind Speed, x and y position of the line equation
line_reg_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], -57, 9.5)
plt.show()
# Out:
# The r-value is: 0.13592714859410276

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
